# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI(model='gpt-4.1', temperature=0.2, max_completion_tokens=200)

# %%
template1 = PromptTemplate(
    template='Write the 5 line essay about {topic}',
    input_variables=['topic']
)

# %%
template2 = PromptTemplate(
    template='Explain in 2 line for the below text /n {text}',
    input_variables=['text']
)

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
parser = StrOutputParser()

# %%
chain = template1 | model | parser | template2 | model | parser

# %%
topic = {'topic':'cricket'}

# %%
result = chain.invoke(topic)

# %%
result
# Out:
# 'Cricket is a widely loved sport played between two teams of eleven, involving batting, bowling, and fielding to score more runs than the opponent. It comes in various formats and teaches teamwork, discipline, and sportsmanship.'
