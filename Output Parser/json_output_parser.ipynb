# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI(model='gpt-4.1', temperature=0.2, max_completion_tokens=300)

# %%
parser = JsonOutputParser()

# %%
template = PromptTemplate(
    template='Give me all the fictional character details of this {movie} \n {format_instruction}',
    input_variables=['movie'],
    partial_variables={'format_instruction': parser.get_format_instructions()}
)

# %%
chain = template | model | parser

# %%
result = chain.invoke({'movie':'Harry Potter'})

# %%
result
# Out:
# {'name': 'Harry James Potter',
#  'gender': 'Male',
#  'species': 'Human (Wizard)',
#  'birth_date': '31 July 1980',
#  'blood_status': 'Half-blood',
#  'family': {'father': 'James Potter',
#   'mother': 'Lily Potter',
#   'godfather': 'Sirius Black',
#   'aunt': 'Petunia Dursley',
#   'uncle': 'Vernon Dursley',
#   'cousin': 'Dudley Dursley'},
#  'house': 'Gryffindor',
#  'school': 'Hogwarts School of Witchcraft and Wizardry',
#  'wand': {'wood': 'Holly', 'core': 'Phoenix feather', 'length': '11 inches'},
#  'patronus': 'Stag',
#  'occupation': ['Student (formerly)',
#   'Auror',
#   'Head of the Department of Magical Law Enforcement'],
#  'notable_titles': ['The Boy Who Lived',
#   'The Chosen One',
#   'Seeker for Gryffindor Quidditch Team',
#   'Triwizard Champion'],
#  'first_appearance': "Harry Potter and the Philosopher's Stone"}
